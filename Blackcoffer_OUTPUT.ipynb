# %%
#Importing necessary librariries
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
import nltk
nltk.download('punkt')
import string
import warnings
import re
import os
warnings.filterwarnings('ignore')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\abz\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.

# %%
#Creating repository of stopwords, positive and negative words from file provided
def stopwords(home_directory):
    child_paths = ['Auditor', 'Currencies', 'DatesandNumbers','Generic', 'GenericLong', 'Geographic', 'Names']
    words=[]
    for child in child_paths:
        with open(os.path.join(home_directory, "Stopwords", f"StopWords_{child}.txt"), 'r', encoding="utf-8", errors="ignore") as f:
            words.extend([word for line in f for word in line.split() if word not in ['\n', '|']])
    return words

def word_sentiment (home_directory, stopwords):
    child_paths = ['positive-words', 'negative-words']
    words = []
    for child in child_paths:
        text = ""
        with open(os.path.join(home_directory, "MasterDictionary/", f"{child}.txt"), 'r', encoding = "utf-8", errors = "ignore") as f:
            words.append([word for line in f for word in line.split() if word not in stopwords+['\n', '|']])
    return words

# %%
#Reading url
def generate_content(url, stopwords):
    try:
        response = requests.get(url)
        response.raise_for_status()
        soup = BeautifulSoup(response.content, 'html.parser')
        text = soup.get_text()
        sentences = nltk.sent_tokenize(text)
        words = nltk.word_tokenize(text)
        words = [word for word in words if word not in string.punctuation]
        words = [word for word in words if word.lower() not in stopwords]
        return sentences, words
    except Exception as e:
        print(f"Error occurred while processing URL: {e}")
        return None, None

# %%
#Word analysis
def word_analysis(words):
    plurals = "aeiouAEIOU"
    total_syallable = 0
    complex_words = 0
    for w in words:
        if not w.endswith(('es', 'ed')):
            syallable = sum([1 for c in w if c in plurals])
            if(syallable > 2): complex_words += 1
            total_syallable += syallable
    syllable_per_word = (total_syallable/len(words))
    complex_percent = (complex_words)/len(words)
    fog_index = 0.4 * (syllable_per_word + complex_percent)
    return syllable_per_word,  complex_words, complex_percent, fog_index

#Pronouns in sentence
def pronoun_counter(sentences):
    pronounRegex = re.compile(r'\b(I|we|my|ours|(?-i:us))\b',re.I)
    pronouns = []
    for s in sentences:
        if s: pronouns.extend(re.findall(pronounRegex, s))
    pronouns_count = sum([1 for w in pronouns])
    return pronouns_count

# %%
home_directory= os.getcwd()
stopwords= stopwords(home_directory)
word_sentiment= word_sentiment (home_directory, stopwords)
pos_words = word_sentiment[0]
neg_words = word_sentiment[1]
df = pd.read_excel(os.path.join(home_directory, "Output Data Structure.xlsx"))
df.head()
# Out:
#             URL_ID                                                URL  \
# 0  blackassign0001  https://insights.blackcoffer.com/rising-it-cit...
# 1  blackassign0002  https://insights.blackcoffer.com/rising-it-cit...
# 2  blackassign0003  https://insights.blackcoffer.com/internet-dema...
# 3  blackassign0004  https://insights.blackcoffer.com/rise-of-cyber...
# 4  blackassign0005  https://insights.blackcoffer.com/ott-platform-...
#
#    POSITIVE SCORE NEGATIVE SCORE  POLARITY SCORE  SUBJECTIVITY SCORE  \
# 0             NaN            NaN             NaN                 NaN
# 1             NaN            NaN             NaN                 NaN
# 2             NaN            NaN             NaN                 NaN
# 3             NaN            NaN             NaN                 NaN
# 4             NaN                            NaN                 NaN
#
#    AVG SENTENCE LENGTH  PERCENTAGE OF COMPLEX WORDS  FOG INDEX  \
# 0                  NaN                          NaN        NaN
# 1                  NaN                          NaN        NaN
# 2                  NaN                          NaN        NaN
# 3                  NaN                          NaN        NaN
# 4                  NaN                          NaN        NaN
#
#    AVG NUMBER OF WORDS PER SENTENCE  COMPLEX WORD COUNT  WORD COUNT  \
# 0                               NaN                 NaN         NaN
# 1                               NaN                 NaN         NaN
# 2                               NaN                 NaN         NaN
# 3                               NaN                 NaN         NaN
# 4                               NaN                 NaN         NaN
#
#    SYLLABLE PER WORD  PERSONAL PRONOUNS  AVG WORD LENGTH
# 0                NaN                NaN              NaN
# 1                NaN                NaN              NaN
# 2                NaN                NaN              NaN
# 3                NaN                NaN              NaN
# 4                NaN                NaN              NaN

# %%
df.columns
# Out:
# Index(['URL_ID', 'URL', 'POSITIVE SCORE', 'NEGATIVE SCORE', 'POLARITY SCORE',
#        'SUBJECTIVITY SCORE', 'AVG SENTENCE LENGTH',
#        'PERCENTAGE OF COMPLEX WORDS', 'FOG INDEX',
#        'AVG NUMBER OF WORDS PER SENTENCE', 'COMPLEX WORD COUNT', 'WORD COUNT',
#        'SYLLABLE PER WORD', 'PERSONAL PRONOUNS', 'AVG WORD LENGTH'],
#       dtype='object')

# %%
#Filling the analysis score for every url
for idx, url in enumerate(df['URL']):
    try:
        response = requests.get(url)
        response.raise_for_status()
        sentences, words = generate_content(url,stopwords)
        pos_score = sum([1 for w in words if w in pos_words])
        neg_score = sum([1 for w in words if w in neg_words])
        syllable_per_word , complex_count, complex_percentage, fog_index = word_analysis(words)
        pronouns_count = pronoun_counter(sentences)
        # Updating data
        df.at[idx, "POSITIVE SCORE"] =  pos_score
        df.at[idx, "NEGATIVE SCORE"] = neg_score
        df.at[idx, "POLARITY SCORE"] = (pos_score - neg_score)/(pos_score + neg_score + 0.000001)
        df.at[idx, 'SUBJECTIVITY SCORE'] = (pos_score + neg_score)/(len(words)+0.000001)
        df.at[idx, 'AVG SENTENCE LENGTH'] = len(words)/len(sentences)
        df.at[idx, 'PERCENTAGE OF COMPLEX WORDS'] = complex_percentage
        df.at[idx, 'FOG INDEX'] = fog_index
        df.at[idx, 'AVG NUMBER OF WORDS PER SENTENCE'] = len(words)/len(sentences)
        df.at[idx, 'COMPLEX WORD COUNT'] = complex_count
        df.at[idx, "WORD COUNT"] = len(words)
        df.at[idx, 'SYLLABLE PER WORD'] = syllable_per_word
        df.at[idx, 'PERSONAL PRONOUNS'] = pronouns_count
        df.at[idx, 'AVG WORD LENGTH'] = sum([len(w) for w in words])/len(words)
    except requests.exceptions.HTTPError as err:
        print(f"HTTPError occurred while processing URL: {url}")
        print(f"Error: {err}")
    except Exception as e:
        print(f"Error occurred while processing URL: {url}")
        print(f"Error: {e}")
# Out:
# HTTPError occurred while processing URL: https://insights.blackcoffer.com/how-neural-networks-can-be-applied-in-various-areas-in-the-future/
# Error: 404 Client Error: Not Found for url: https://insights.blackcoffer.com/how-neural-networks-can-be-applied-in-various-areas-in-the-future/
# HTTPError occurred while processing URL: https://insights.blackcoffer.com/covid-19-environmental-impact-for-the-future/
# Error: 404 Client Error: Not Found for url: https://insights.blackcoffer.com/covid-19-environmental-impact-for-the-future/
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error occurred while processing URL: nan
# Error: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?

# %%
df.tail()
# Out:
#                                                    URL_ID  URL  \
# https://insights.blackcoffer.com/what-is-the-re...    NaN  NaN
# https://insights.blackcoffer.com/impact-of-covi...    NaN  NaN
# https://insights.blackcoffer.com/contribution-o...    NaN  NaN
# https://insights.blackcoffer.com/how-covid-19-i...    NaN  NaN
# https://insights.blackcoffer.com/how-will-covid...    NaN  NaN
#
#                                                     POSITIVE SCORE  \
# https://insights.blackcoffer.com/what-is-the-re...            33.0
# https://insights.blackcoffer.com/impact-of-covi...            27.0
# https://insights.blackcoffer.com/contribution-o...            11.0
# https://insights.blackcoffer.com/how-covid-19-i...            19.0
# https://insights.blackcoffer.com/how-will-covid...            40.0
#
#                                                    NEGATIVE SCORE  \
# https://insights.blackcoffer.com/what-is-the-re...             56
# https://insights.blackcoffer.com/impact-of-covi...             35
# https://insights.blackcoffer.com/contribution-o...              2
# https://insights.blackcoffer.com/how-covid-19-i...              3
# https://insights.blackcoffer.com/how-will-covid...             55
#
#                                                     POLARITY SCORE  \
# https://insights.blackcoffer.com/what-is-the-re...       -0.258427
# https://insights.blackcoffer.com/impact-of-covi...       -0.129032
# https://insights.blackcoffer.com/contribution-o...        0.692308
# https://insights.blackcoffer.com/how-covid-19-i...        0.727273
# https://insights.blackcoffer.com/how-will-covid...       -0.157895
#
#                                                     SUBJECTIVITY SCORE  \
# https://insights.blackcoffer.com/what-is-the-re...            0.071257
# https://insights.blackcoffer.com/impact-of-covi...            0.056007
# https://insights.blackcoffer.com/contribution-o...            0.014428
# https://insights.blackcoffer.com/how-covid-19-i...            0.022044
# https://insights.blackcoffer.com/how-will-covid...            0.076000
#
#                                                     AVG SENTENCE LENGTH  \
# https://insights.blackcoffer.com/what-is-the-re...            20.145161
# https://insights.blackcoffer.com/impact-of-covi...            22.140000
# https://insights.blackcoffer.com/contribution-o...            40.954545
# https://insights.blackcoffer.com/how-covid-19-i...            23.761905
# https://insights.blackcoffer.com/how-will-covid...            29.069767
#
#                                                     PERCENTAGE OF COMPLEX WORDS  \
# https://insights.blackcoffer.com/what-is-the-re...                     0.444355
# https://insights.blackcoffer.com/impact-of-covi...                     0.420054
# https://insights.blackcoffer.com/contribution-o...                     0.480577
# https://insights.blackcoffer.com/how-covid-19-i...                     0.426854
# https://insights.blackcoffer.com/how-will-covid...                     0.424000
#
#                                                     FOG INDEX  \
# https://insights.blackcoffer.com/what-is-the-re...   1.154844
# https://insights.blackcoffer.com/impact-of-covi...   1.106775
# https://insights.blackcoffer.com/contribution-o...   1.204883
# https://insights.blackcoffer.com/how-covid-19-i...   1.132265
# https://insights.blackcoffer.com/how-will-covid...   1.109120
#
#                                                     AVG NUMBER OF WORDS PER SENTENCE  \
# https://insights.blackcoffer.com/what-is-the-re...                         20.145161
# https://insights.blackcoffer.com/impact-of-covi...                         22.140000
# https://insights.blackcoffer.com/contribution-o...                         40.954545
# https://insights.blackcoffer.com/how-covid-19-i...                         23.761905
# https://insights.blackcoffer.com/how-will-covid...                         29.069767
#
#                                                     COMPLEX WORD COUNT  \
# https://insights.blackcoffer.com/what-is-the-re...               555.0
# https://insights.blackcoffer.com/impact-of-covi...               465.0
# https://insights.blackcoffer.com/contribution-o...               433.0
# https://insights.blackcoffer.com/how-covid-19-i...               426.0
# https://insights.blackcoffer.com/how-will-covid...               530.0
#
#                                                     WORD COUNT  \
# https://insights.blackcoffer.com/what-is-the-re...      1249.0
# https://insights.blackcoffer.com/impact-of-covi...      1107.0
# https://insights.blackcoffer.com/contribution-o...       901.0
# https://insights.blackcoffer.com/how-covid-19-i...       998.0
# https://insights.blackcoffer.com/how-will-covid...      1250.0
#
#                                                     SYLLABLE PER WORD  \
# https://insights.blackcoffer.com/what-is-the-re...           2.442754
# https://insights.blackcoffer.com/impact-of-covi...           2.346883
# https://insights.blackcoffer.com/contribution-o...           2.531632
# https://insights.blackcoffer.com/how-covid-19-i...           2.403808
# https://insights.blackcoffer.com/how-will-covid...           2.348800
#
#                                                     PERSONAL PRONOUNS  \
# https://insights.blackcoffer.com/what-is-the-re...               27.0
# https://insights.blackcoffer.com/impact-of-covi...               29.0
# https://insights.blackcoffer.com/contribution-o...               22.0
# https://insights.blackcoffer.com/how-covid-19-i...               26.0
# https://insights.blackcoffer.com/how-will-covid...               25.0
#
#                                                     AVG WORD LENGTH
# https://insights.blackcoffer.com/what-is-the-re...         7.534828
# https://insights.blackcoffer.com/impact-of-covi...         7.273713
# https://insights.blackcoffer.com/contribution-o...         7.598224
# https://insights.blackcoffer.com/how-covid-19-i...         7.328657
# https://insights.blackcoffer.com/how-will-covid...         7.439200

# %%
df.isna().sum()
# Out:
# URL_ID                              98
# URL                                 98
# POSITIVE SCORE                       2
# NEGATIVE SCORE                       2
# POLARITY SCORE                       2
# SUBJECTIVITY SCORE                   2
# AVG SENTENCE LENGTH                  2
# PERCENTAGE OF COMPLEX WORDS          2
# FOG INDEX                            2
# AVG NUMBER OF WORDS PER SENTENCE     2
# COMPLEX WORD COUNT                   2
# WORD COUNT                           2
# SYLLABLE PER WORD                    2
# PERSONAL PRONOUNS                    2
# AVG WORD LENGTH                      2
# dtype: int64

# %%
df.to_csv('Blackcoffer_OUTPUT.csv', index=False)
